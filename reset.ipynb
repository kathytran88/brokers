# %%
import pandas as pd

# %%
df = pd.read_excel('ibba_final.xlsx')
df.head()
# Out:
#    Unnamed: 0            name                                       company  \
# 0         939     0fir Sagron  eXp Commercial - Business Brokerage Division
# 1        1955  A. Bert Risdon               Florida Business Exchange, Inc.
# 2         556       AJ Ramsey                                           RRG
# 3        1131   ALDINA MACIEL                                           NaN
# 4        2232  ALEX KEYLIKHES                  TRANSWORLD BUSINESS ADVISORS
#
#                      location           phone  \
# 0  West Hollywood, California    424-239-9920
# 1      Daytona Beach, Florida    386-310-2211
# 2        Cary, North Carolina      9193256611
# 3     Watsonville, California    831-840-1360
# 4              Miami, Florida  (305) 799-0729
#
#                                              profile  \
# 0  https://www.ibba.org/broker-profile/california...
# 1  https://www.ibba.org/broker-profile/florida/da...
# 2  https://www.ibba.org/broker-profile/north-caro...
# ...

# %%
df = df.drop('Unnamed: 0', axis = 1)
df.head()
# Out:
#              name                                       company  \
# 0     0fir Sagron  eXp Commercial - Business Brokerage Division
# 1  A. Bert Risdon               Florida Business Exchange, Inc.
# 2       AJ Ramsey                                           RRG
# 3   ALDINA MACIEL                                           NaN
# 4  ALEX KEYLIKHES                  TRANSWORLD BUSINESS ADVISORS
#
#                      location           phone  \
# 0  West Hollywood, California    424-239-9920
# 1      Daytona Beach, Florida    386-310-2211
# 2        Cary, North Carolina      9193256611
# 3     Watsonville, California    831-840-1360
# 4              Miami, Florida  (305) 799-0729
#
#                                              profile  \
# 0  https://www.ibba.org/broker-profile/california...
# 1  https://www.ibba.org/broker-profile/florida/da...
# 2  https://www.ibba.org/broker-profile/north-caro...
# 3  https://www.ibba.org/broker-profile/california...
# ...

# %%
df.to_excel('ibba_brokers.xlsx')
